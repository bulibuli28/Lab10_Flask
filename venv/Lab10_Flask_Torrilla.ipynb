# %%
import os

os.makedirs("templates", exist_ok=True)
os.makedirs("static/images", exist_ok=True)
os.makedirs("static/css", exist_ok=True)

# Step 2: Create essential files
files = [
    "app.py",
    "models.py",
    "forms.py",
    "requirements.txt",
    "templates/base.html",
    "templates/home.html",
    "templates/about.html",
    "templates/contact.html",
    "templates/login.html",
    "templates/register.html",
    "templates/students.html"
]

for file in files:
    with open(file, "w") as f:
        pass  # Create empty file

print("Project structure and files created.")
# Out:
# Running cells with 'Python 3.15.0' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/matthew/flask_app1/venv/Scripts/python.exe -m pip install ipykernel -U --user --force-reinstall'
